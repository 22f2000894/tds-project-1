# %% [markdown]
# # TDS PROJECT 1
# Using the GitHub API, scrape all users in the city of Hyderabad with over 50 followers, and their repositories.

# %%
users_url ="https://raw.githubusercontent.com/22f2000894/tds-project-1/refs/heads/main/users.csv"
repositories_url ="https://raw.githubusercontent.com/22f2000894/tds-project-1/refs/heads/main/repositories.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(users_url)

# Display the first few rows
df.head()
# Out:
#              login                 name                   company  \
# 0   iam-veeramalla  Abhishek Veeramalla                   RED HAT
# 1      in28minutes                  NaN               IN28MINUTES
# 2    stacksimplify        STACKSIMPLIFY             STACKSIMPLIFY
# 3  thenaveensaggam        NAVEEN SAGGAM  HTTPS://WWW.UIBRAINS.COM
# 4       MadhavBahl          MADHAV BAHL                 MICROSOFT
#
#            location                      email hireable  \
# 0  Hyderabad, India                        NaN      NaN
# 1  Hyderabad, India      in28minutes@gmail.com     True
# 2         Hyderabad    stacksimplify@gmail.com      NaN
# 3         Hyderabad  thenaveensaggam@gmail.com      NaN
# 4  Hyderabad, India     madhavbahl10@gmail.com     True
#
#                                                  bio  public_repos  followers  \
# 0  Keep learning, sharing and growing || Principa...            63      16262
# ...

# %%
# upload csv files

#from google.colab import files
#uploaded = files.upload()

# %%
#repositories = pd.read_csv('repositories.csv')
repositories= pd.read_csv(repositories_url)
repositories.head()
# Out:
#             login              full_name            created_at  \
# 0  iam-veeramalla  gitops-console-plugin  2022-07-13T19:06:47Z
# 1  iam-veeramalla        gitops-operator  2020-06-26T13:38:35Z
# 2  iam-veeramalla  argo-rollouts-manager  2023-04-10T09:37:37Z
# 3  iam-veeramalla        argocd-operator  2019-12-04T01:35:55Z
# 4  iam-veeramalla         k8s-bigip-ctlr  2017-03-09T16:24:02Z
#
#    stargazers_count  watchers_count    language  has_projects  has_wiki  \
# 0                 2              18  TypeScript          True      True
# 1               151              18          Go          True      True
# 2                98               6          Go          True      True
# 3               648              23          Go         False     False
# 4               359              46          Go         False     False
#
#   license_name
# 0          NaN
# 1   apache-2.0
# 2   apache-2.0
# 3   apache-2.0
# 4   apache-2.0

# %% [markdown]
# ##  **Q1. Who are the top 5 users in Hyderabad with the highest number of followers? List their login in order, comma-separated.**
# Users

# %%
#users = pd.read_csv('users.csv')
users = pd.read_csv(users_url)
users.head()
# Out:
#              login                 name                   company  \
# 0   iam-veeramalla  Abhishek Veeramalla                   RED HAT
# 1      in28minutes                  NaN               IN28MINUTES
# 2    stacksimplify        STACKSIMPLIFY             STACKSIMPLIFY
# 3  thenaveensaggam        NAVEEN SAGGAM  HTTPS://WWW.UIBRAINS.COM
# 4       MadhavBahl          MADHAV BAHL                 MICROSOFT
#
#            location                      email hireable  \
# 0  Hyderabad, India                        NaN      NaN
# 1  Hyderabad, India      in28minutes@gmail.com     True
# 2         Hyderabad    stacksimplify@gmail.com      NaN
# 3         Hyderabad  thenaveensaggam@gmail.com      NaN
# 4  Hyderabad, India     madhavbahl10@gmail.com     True
#
#                                                  bio  public_repos  followers  \
# 0  Keep learning, sharing and growing || Principa...            63      16262
# ...

# %%
# convert created_at to datetime
users['created_at'] = pd.to_datetime(users['created_at'])
repositories['created_at'] = pd.to_datetime(repositories['created_at'])

# %%
# top 5 users have highest number of followers
top5_users = users.sort_values(by='followers', ascending=False).head(5)
print(','.join(top5_users['login'].tolist()))
top5_users
# Out:
# iam-veeramalla,in28minutes,stacksimplify,thenaveensaggam,MadhavBahl
#              login                 name                   company  \
# 0   iam-veeramalla  Abhishek Veeramalla                   RED HAT
# 1      in28minutes                  NaN               IN28MINUTES
# 2    stacksimplify        STACKSIMPLIFY             STACKSIMPLIFY
# 3  thenaveensaggam        NAVEEN SAGGAM  HTTPS://WWW.UIBRAINS.COM
# 4       MadhavBahl          MADHAV BAHL                 MICROSOFT
#
#            location                      email hireable  \
# 0  Hyderabad, India                        NaN      NaN
# 1  Hyderabad, India      in28minutes@gmail.com     True
# 2         Hyderabad    stacksimplify@gmail.com      NaN
# 3         Hyderabad  thenaveensaggam@gmail.com      NaN
# 4  Hyderabad, India     madhavbahl10@gmail.com     True
#
#                                                  bio  public_repos  followers  \
# 0  Keep learning, sharing and growing || Principa...            63      16262
# ...

# %%
top_5_users = users.nlargest(5, 'followers')['login']
print(",".join(top_5_users))
# Out:
# iam-veeramalla,in28minutes,stacksimplify,thenaveensaggam,MadhavBahl

# %% [markdown]
# ## **Q2. Who are the 5 earliest registered GitHub users in Hyderabad? List their login in ascending order of created_at, comma-separated.**
# Users

# %%
earliest_users = users.sort_values(by='created_at').head(5)
print(','.join(earliest_users['login'].tolist()))
earliest_users
# Out:
# shabda,sitaramc,bagwanpankaj,srikanthlogic,kulbirsaini
#              login              name company                    location  \
# 87          shabda       Shabda Raaj  AGILIQ            Hyderabad, India
# 27        sitaramc  Sitaram Chamarty     NaN            Hyderabad, India
# 479   bagwanpankaj     Pankaj Bagwan     NaN  Jaipur | Hyderabad (India)
# 258  srikanthlogic        Srikanth L     NaN                   Hyderabad
# 471    kulbirsaini      Kulbir Saini     NaN            Hyderabad, India
#
#                   email hireable                              bio  \
# 87    shabda@agiliq.com     True  I build @django apps at @agiliq
# 27   sitaramc@gmail.com      NaN                              NaN
# 479                 NaN     True                              NaN
# 258                 NaN     True                              NaN
# 471                 NaN      NaN                              NaN
#
#      public_repos  followers  following                created_at
# ...

# %% [markdown]
# ## **3. What are the 3 most popular license among these users? Ignore missing licenses. List the license_name in order, comma-separated.**
# Licenses

# %%
most_popular_licenses = repositories.groupby('license_name').size().sort_values(ascending=False).head(4)
print(','.join(most_popular_licenses.index.tolist()))
most_popular_licenses
# Out:
# mit,apache-2.0,other,gpl-3.0
# license_name
# mit           6427
# apache-2.0    2085
# other         1981
# gpl-3.0       1052
# dtype: int64

# %%
license_counts = repositories['license_name'].dropna().value_counts()
top_3_licenses = license_counts.head(3).index.tolist()
print(",".join(top_3_licenses))
# Out:
# mit,apache-2.0,other

# %% [markdown]
# ### **Q4. Which company do the majority of these developers work at?**
# Company (cleaned up as explained above)

# %%
majority_company = users['company'].mode()
print(majority_company)
# Out:
# 0    IIIT HYDERABAD
# 1         MICROSOFT
# Name: company, dtype: object

# %% [markdown]
# ## **Q5. Which programming language is most popular among these users?**
# Language

# %%
most_popular_language = repositories['language'].mode()[0]
print(most_popular_language)
# Out:
# JavaScript

# %% [markdown]
# ## **Q6. Which programming language is the second most popular among users who joined after 2020?**
# Language

# %%
post_2020_df = users[users['created_at'] > '2020-01-01']
post_2020_repos = repositories[repositories['login'].isin(post_2020_df['login'])]
second_language = post_2020_repos['language'].value_counts().index[1]
print(second_language)
# Out:
# HTML

# %% [markdown]
# ## **Q7. Which language has the highest average number of stars per repository?**
# Language

# %%
language_avg_stars = repositories.groupby('language')['stargazers_count'].mean()
top_language_by_stars = language_avg_stars.idxmax()
print(top_language_by_stars)
# Out:
# Perl

# %% [markdown]
# ## **Q8. Let's define leader_strength as followers / (1 + following). Who are the top 5 in terms of leader_strength? List their login in order, comma-separated.**
# User login

# %%
users['leader_strength'] = users['followers'] / (1 + users['following'])
top_5_leader_strength = users.nlargest(5, 'leader_strength')['login']
print(",".join(top_5_leader_strength))
# Out:
# in28minutes,iam-veeramalla,stacksimplify,ashokitschool,thenaveensaggam

# %% [markdown]
# ## **Q9. What is the correlation between the number of followers and the number of public repositories among users in Hyderabad?**
# Correlation between followers and repos (to 3 decimal places, e.g. 0.123 or -0.123)

# %%
correlation = users[['followers', 'public_repos']].corr().iloc[0, 1]
print(f"{correlation:.3f}")
# Out:
# 0.013

# %% [markdown]
# ## **Q10. Does creating more repos help users get more followers? Using regression, estimate how many additional followers a user gets per additional public repository.**
# Regression slope of followers on repos (to 3 decimal places, e.g. 0.123 or -0.123)

# %%
slope = np.polyfit(users['public_repos'], users['followers'], 1)[0]
print(f"{slope:.3f}")
# Out:
# 0.168

# %% [markdown]
# ## **Q11. Do people typically enable projects and wikis together? What is the correlation between a repo having projects enabled and having wiki enabled?**
# Correlation between projects and wiki enabled (to 3 decimal places, e.g. 0.123 or -0.123)

# %%
correlation_projects_wiki = repositories[['has_projects', 'has_wiki']].corr().iloc[0, 1]
print(f"{correlation_projects_wiki:.3f}")
# Out:
# 0.391

# %%
# Calculate the correlation
correlation = repositories['has_projects'].corr(repositories['has_wiki'])

# Display the result rounded to three decimal places
print(f"Correlation between projects and wiki enabled: {correlation:.3f}")
repositories.head()
# Out:
# Correlation between projects and wiki enabled: 0.391
#             login              full_name                created_at  \
# 0  iam-veeramalla  gitops-console-plugin 2022-07-13 19:06:47+00:00
# 1  iam-veeramalla        gitops-operator 2020-06-26 13:38:35+00:00
# 2  iam-veeramalla  argo-rollouts-manager 2023-04-10 09:37:37+00:00
# 3  iam-veeramalla        argocd-operator 2019-12-04 01:35:55+00:00
# 4  iam-veeramalla         k8s-bigip-ctlr 2017-03-09 16:24:02+00:00
#
#    stargazers_count  watchers_count    language  has_projects  has_wiki  \
# 0                 2              18  TypeScript          True      True
# 1               151              18          Go          True      True
# 2                98               6          Go          True      True
# 3               648              23          Go         False     False
# 4               359              46          Go         False     False
#
#   license_name
# 0          NaN
# 1   apache-2.0
# 2   apache-2.0
# ...

# %% [markdown]
# ## **Q12. Do hireable users follow more people than those who are not hireable?**
# Average of following per user for hireable=true minus the average following for the rest (to 3 decimal places, e.g. 12.345 or -12.345)

# %%
users['hireable'] = users['hireable'].fillna(False)
avg_following_hireable = users[users['hireable'] == True]['following'].mean()
avg_following_non_hireable = users[users['hireable'] == False]['following'].mean()
print(f"{avg_following_hireable:.3f}")
print(f"{avg_following_non_hireable:.3f}")
following_difference = avg_following_hireable - avg_following_non_hireable
print(f"{following_difference:.3f}")
# Out:
# 108.436
# 76.500
# 31.936
# <ipython-input-53-7ffb0aae2214>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   users['hireable'] = users['hireable'].fillna(False)

# %% [markdown]
# ## **13. Some developers write long bios. Does that help them get more followers? What's the impact of the length of their bio (in Unicode words, split by whitespace) with followers? (Ignore people without bios)**
# Regression slope of followers on bio word count (to 3 decimal places, e.g. 12.345 or -12.345)

# %%
# ------------------------------


from sklearn.linear_model import LinearRegression
import numpy as np

# Filter out rows where 'bio' is NaN (i.e., users without a bio)
users_df = pd.read_csv(users_url)
users_with_bio = users_df[users_df['bio'].notna()]

# Calculate word count for each bio
users_with_bio['bio_word_count'] = users_with_bio['bio'].apply(lambda x: len(x.split(' ')))

# Extract bio word counts and followers as separate arrays for regression
X = users_with_bio[['bio_word_count']]
y = users_with_bio['followers']

# Perform linear regression to get the slope
regression_model = LinearRegression().fit(X, y)
slope = regression_model.coef_[0]  # Get the slope of followers with respect to bio word count

print(slope)
# Out:
# 7.0502182647420275
# <ipython-input-54-4b8d4b1fbf39>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users_with_bio['bio_word_count'] = users_with_bio['bio'].apply(lambda x: len(x.split(' ')))

# %% [markdown]
# ## **Q14. Who created the most repositories on weekends (UTC)? List the top 5 users' login in order, comma-separated**
# User login

# %%
repositories['day_of_week'] = repositories['created_at'].dt.dayofweek
weekend_repos = repositories[repositories['day_of_week'] >= 5]  # 5 = Saturday, 6 = Sunday
top_5_weekend_users = weekend_repos['login'].value_counts().head(5).index
print(",".join(top_5_weekend_users))
# Out:
# hemanth22,anjijava16,wahidKhan74,elevenpassin,narasimhavuppala

# %% [markdown]
# ## **Q15. Do people who are hireable share their email addresses more often?**
# [fraction of users with email when hireable=true] minus [fraction of users with email for the rest] (to 3 decimal places, e.g. 0.123 or -0.123)

# %%
# hirable field null to false

users['hireable'] = users['hireable'].fillna(False)

hireable_emails = users[users['hireable'] == True]['email'].notnull().mean()
non_hireable_emails = users[users['hireable'] == False]['email'].notnull().mean()
email_difference = hireable_emails - non_hireable_emails
print(f"{email_difference:.3f}")
# Out:
# 0.268

# %% [markdown]
# ## **Q16. Let's assume that the last word in a user's name is their surname (ignore missing names, trim and split by whitespace.) What's the most common surname? (If there's a tie, list them all, comma-separated, alphabetically)**
# Most common surname(s)

# %%
users['surname'] = users['name'].fillna("").apply(lambda x: x.split()[-1] if x else "")
most_common_surname = users['surname'].mode()[0]
surname_count = users[users['surname'] == most_common_surname].shape[0]
print(most_common_surname)
print(surname_count)
# Out:
# Kumar
# 12

# %% [markdown]
# ## Data Analysis on `users.csv` and `repositories.csv`.

# %%
# prompt: do data analysis on csv files key points all fields and summarize

import pandas as pd
import numpy as np

# Load the datasets
users_url = "https://raw.githubusercontent.com/22f2000894/tds-project-1/refs/heads/main/users.csv"
repositories_url = "https://raw.githubusercontent.com/22f2000894/tds-project-1/refs/heads/main/repositories.csv"
users = pd.read_csv(users_url)
repositories = pd.read_csv(repositories_url)

# Convert date columns to datetime objects
users['created_at'] = pd.to_datetime(users['created_at'])
repositories['created_at'] = pd.to_datetime(repositories['created_at'])

# --- Data Exploration and Summary ---
print("Users Data Overview:")
print(users.info())
print(users.describe())
print("\nRepositories Data Overview:")
print(repositories.info())
print(repositories.describe())

# Key points and summaries for each field:

# Users:
# - login: Unique identifier for each user.
# - id: Unique numerical ID.
# - node_id: Another unique identifier.
# - avatar_url: URL to the user's avatar image.
# - gravatar_id: Gravatar ID.
# - url: User's profile URL.
# - html_url: HTML URL to the user's profile.
# - followers_url: URL to the list of followers.
# - following_url: URL to the list of users this user follows.
# - gists_url: URL to the user's gists.
# - starred_url: URL to the user's starred repositories.
# - subscriptions_url: URL to the user's subscriptions.
# - organizations_url: URL to the user's organizations.
# - repos_url: URL to the user's repositories.
# - events_url: URL to the user's events.
# - received_events_url: URL to events received by the user.
# - type: Type of user (usually "User").
# - site_admin: Indicates if the user is a site administrator.
# - name: User's full name.
# - company: User's company.
# - blog: User's blog URL.
# - location: User's location.
# - email: User's email address.
# - hireable: Indicates if the user is open to hiring.
# - bio: User's bio.
# - twitter_username: User's Twitter username.
# - public_repos: Number of public repositories.
# - public_gists: Number of public gists.
# - followers: Number of followers.
# - following: Number of users the user follows.
# - created_at: Date when the user account was created.
# - updated_at: Date when the user profile was last updated.


# Repositories:
# - id: Unique numerical ID.
# - node_id: Another unique identifier.
# - name: Repository name.
# - full_name: Full repository name (owner/repo).
# - owner: Owner information (may include nested data).
# - private: Indicates if the repository is private.
# - html_url: HTML URL to the repository.
# - description: Repository description.
# - fork: Indicates if the repository is a fork.
# - url: Repository URL.
# - created_at: Date when the repository was created.
# - updated_at: Date when the repository was last updated.
# - pushed_at: Date of the last push to the repository.
# - homepage: Repository homepage URL.
# - size: Size of the repository in kilobytes.
# - stargazers_count: Number of stars.
# - watchers_count: Number of watchers.
# - language: Programming language used in the repository.
# - forks_count: Number of forks.
# - open_issues_count: Number of open issues.
# - master_branch: Main branch name.
# - default_branch: Default branch name.
# - score: A relevance score.
# - topics: List of topics related to the repository.
# - license: Information about the repository's license.


# Further Analysis (examples):

# Missing values
print("\nMissing Values in Users:")
print(users.isnull().sum())
print("\nMissing Values in Repositories:")
print(repositories.isnull().sum())


# Correlation analysis (example)
correlation_matrix = users[['followers', 'public_repos']].corr()
print("\nCorrelation Matrix (Followers vs. Public Repos):")
correlation_matrix
# Out:
# Users Data Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   login         499 non-null    object
#  1   name          493 non-null    object
#  2   company       319 non-null    object
#  3   location      499 non-null    object
#  4   email         259 non-null    object
#  5   hireable      195 non-null    object
#  6   bio           414 non-null    object
#  7   public_repos  499 non-null    int64
#  8   followers     499 non-null    int64
#  9   following     499 non-null    int64
#  10  created_at    499 non-null    datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), int64(3), object(7)
# memory usage: 43.0+ KB
# None
#        public_repos     followers    following
# count    499.000000    499.000000   499.000000
# mean      76.643287    205.921844    88.979960
# std       78.375070    989.407737   229.767386
# ...

# %%
# hirable field null to false

users['hireable'] = users['hireable'].fillna(False)
# Out:
# <ipython-input-59-f7566e5a185b>:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   users['hireable'] = users['hireable'].fillna(False)

# %%
correlation_matrix = users[['followers', 'public_repos','following','hireable']].corr()
correlation_matrix
# Out:
#               followers  public_repos  following  hireable
# followers      1.000000      0.013283  -0.018214  0.010610
# public_repos   0.013283      1.000000   0.133910  0.113966
# following     -0.018214      0.133910   1.000000  0.067886
# hireable       0.010610      0.113966   0.067886  1.000000

# %%
# prompt: correlation_matrix use and generate  summary in sentance

# Assuming 'correlation_matrix' is already calculated as in your provided code

# Generate a summary of the correlation matrix
def summarize_correlation_matrix(correlation_matrix):
    summary = []
    for col in correlation_matrix.columns:
        for index in correlation_matrix.index:
            if col != index:
                correlation = correlation_matrix.loc[index, col]
                if abs(correlation) > 0.1:  # Consider correlations above 0.1 as significant
                    summary.append(f"There is a {'positive' if correlation > 0 else 'negative'} correlation between {index} and {col} (r = {correlation:.3f}).")
    return ". ".join(summary)

summary_text = summarize_correlation_matrix(correlation_matrix)
summary_text
# Out:
# 'There is a positive correlation between following and public_repos (r = 0.134).. There is a positive correlation between hireable and public_repos (r = 0.114).. There is a positive correlation between public_repos and following (r = 0.134).. There is a positive correlation between public_repos and hireable (r = 0.114).'

# %%
# correlation matrix of variable of repositories


# Calculate the correlation matrix for specified columns
correlation_matrix = repositories[['stargazers_count', 'has_wiki','has_projects','watchers_count']].corr()

# correlation matrix
correlation_matrix
# Out:
#                   stargazers_count  has_wiki  has_projects  watchers_count
# stargazers_count          1.000000 -0.039558     -0.038564        0.732292
# has_wiki                 -0.039558  1.000000      0.391453       -0.109832
# has_projects             -0.038564  0.391453      1.000000       -0.203274
# watchers_count            0.732292 -0.109832     -0.203274        1.000000
